# %%
from joblib import dump, load
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
import pickle
clf = load('MultinomialNB.joblib')
# vocab = load('vocab.joblib')
tf1 = load(open("tfidf1.pkl", 'rb'))

# %%
tf1_new = TfidfVectorizer(sublinear_tf=True, stop_words = "english", lowercase = True, vocabulary = tf1.vocabulary_,encoding='utf-8')
X_tf1 = tf1_new.fit_transform(['its a very happy time today!!'])
        # q = tfidf.fit_transform([tweet])
analysis = clf.predict(X_tf1)

# %%
analysis
# Out:
# array([1], dtype=int64)

# %%
X_tf1
# Out:
# <1x249644 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
tf1.get_feature_names()
# Out:
# ['00',
#  '000',
#  '0000',
#  '000000000000',
#  '000001',
#  '0000ff',
#  '0007',
#  '000aah',
#  '000followers',
#  '000follows',
#  '000ft',
#  '000g',
#  '000gbp',
#  '000h',
#  '000hrs',
#  '000k',
#  '000kg',
#  '000km',
#  '000kms',
#  '000mah',
#  '000mnt',
#  '000pv',
#  '000s',
#  '000th',
#  '000thb',
#  '000watts',
#  '000yrs',
#  '001',
#  '0010utc',
#  '0011000100101011001100010011110100110010',
#  '0012',
#  '001st',
#  '002',
#  '00202',
#  '0022',
#  '003r',
#  '003ï',
#  '004',
#  '0047',
#  '005mm',
#  '006',
#  '0069',
#  '007',
#  '007peter',
#  '008',
#  '0084',
#  '00a',
#  '00am',
#  '00ff00',
#  '00g',
#  '00ga',
#  '00h',
#  '00hrs',
#  '00hs',
#  '00o',
#  '00p',
#  '00pm',
#  '00pn',
#  '00psz',
#  '00th',
#  '01',
#  '010',
#  '0100',
#  '0105',
#  '011',
#  '01189998819991197253',
#  '01253',
#  '0130',
#  '013th',
#  '014',
#  '015',
#  '01614948343',
#  '0162970983',
#  '018',
#  '019',
#  '0191',
#  '01am',
#  '01percent',
#  '01pm',
#  '01s',
# ...
